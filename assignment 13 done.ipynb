# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Salaries.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df1 = df[((df['EmployeeName'] == 'Not provided') & (df['JobTitle'] == 'Not provided'))]
df1
# Out:
#             Id  EmployeeName      JobTitle       BasePay   OvertimePay  \
# 148646  148647  Not provided  Not provided  Not Provided  Not Provided
# 148650  148651  Not provided  Not provided  Not Provided  Not Provided
# 148651  148652  Not provided  Not provided  Not Provided  Not Provided
# 148652  148653  Not provided  Not provided  Not Provided  Not Provided
#
#             OtherPay      Benefits  TotalPay  TotalPayBenefits  Year  Notes  \
# 148646  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148650  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148651  Not Provided  Not Provided       0.0               0.0  2014    NaN
# 148652  Not Provided  Not Provided       0.0               0.0  2014    NaN
#
#                Agency Status
# 148646  San Francisco    NaN
# 148650  San Francisco    NaN
# 148651  San Francisco    NaN
# 148652  San Francisco    NaN

# %%
df2 = df[["BasePay", "OvertimePay", "OtherPay", "Benefits"]].replace('Not provided', 0)
df2
# Out:
#              BasePay   OvertimePay      OtherPay      Benefits
# 0          167411.18           0.0     400184.25           NaN
# 1          155966.02     245131.88     137811.38           NaN
# 2          212739.13     106088.18       16452.6           NaN
# 3            77916.0      56120.71      198306.9           NaN
# 4           134401.6        9737.0     182234.59           NaN
# ...              ...           ...           ...           ...
# 148649          0.00          0.00          0.00          0.00
# 148650  Not Provided  Not Provided  Not Provided  Not Provided
# 148651  Not Provided  Not Provided  Not Provided  Not Provided
# 148652  Not Provided  Not Provided  Not Provided  Not Provided
# 148653          0.00          0.00       -618.13          0.00
#
# [148654 rows x 4 columns]

# %%
df3 = df[["BasePay", "OvertimePay", "OtherPay", "Benefits"]]

df3
# Out:
#              BasePay   OvertimePay      OtherPay      Benefits
# 0          167411.18           0.0     400184.25           NaN
# 1          155966.02     245131.88     137811.38           NaN
# 2          212739.13     106088.18       16452.6           NaN
# 3            77916.0      56120.71      198306.9           NaN
# 4           134401.6        9737.0     182234.59           NaN
# ...              ...           ...           ...           ...
# 148649          0.00          0.00          0.00          0.00
# 148650  Not Provided  Not Provided  Not Provided  Not Provided
# 148651  Not Provided  Not Provided  Not Provided  Not Provided
# 148652  Not Provided  Not Provided  Not Provided  Not Provided
# 148653          0.00          0.00       -618.13          0.00
#
# [148654 rows x 4 columns]

# %%
df4 = df[df['BasePay'] > 200000][['EmployeeName', 'BasePay']]
df4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df4 = df[df['BasePay'] > 200000][['EmployeeName', 'BasePay']]
#       2 df4
#
# File ~\Jupyter\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\Jupyter\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\Jupyter\Lib\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
df5 = df[df['JobTitle'].str.contains('manager', case=False)][['EmployeeName', 'JobTitle']]
df5
# Out:
#                 EmployeeName                                        JobTitle
# 0             NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 83            EDWARD REISKIN  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 87               KEVIN BARRY                                     MANAGER VII
# 95              MIVIC HIROSE                                    MANAGER VIII
# 162            JULIE LABONTE                                    MANAGER VIII
# ...                      ...                                             ...
# 147216  Steven D Koneffklatt                                     Manager III
# 147502    Alice B Villagomez                                      Manager IV
# 147805    Stephen C Laplante                                      Manager II
# 148150      Shirley M Parker                           Real Property Manager
# 148475         James P Horan                                      Manager IV
#
# [4110 rows x 2 columns]

# %%
df6 = df[['EmployeeName', 'JobTitle', 'TotalPay']]
df6
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#          TotalPay
# 0       567595.43
# 1       538909.28
# 2       335279.91
# ...

# %%
df7 = df[df['OvertimePay'] == 0].shape[0]
df7
# Out:
# 66103

# %%
df_filter = df[df['TotalPay'] > 300000]
df8 = df_filter.groupby('JobTitle')['TotalPay'].sum().reset_index()
df8
# Out:
#                                           JobTitle    TotalPay
# 0                        ASSISTANT DEPUTY CHIEF II   316285.74
# 1                         Assistant Deputy Chief 2   654066.15
# 2                     Asst Chf of Dept (Fire Dept)  1303828.26
# 3                                Asst Med Examiner  1069837.40
# 4               BATTALION CHIEF, (FIRE DEPARTMENT)   619408.60
# 5                   Battalion Chief, Fire Suppress  2845960.11
# 6                   Battlion Chief, Fire Suppressi  1266054.40
# 7                  CAPTAIN III (POLICE DEPARTMENT)   874189.19
# 8           CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)   302377.73
# 9                                        Captain 3  1274613.48
# 10                       Captain, Fire Suppression   610671.88
# 11                        Chief Investment Officer   339653.70
# 12                                 Chief of Police   987550.94
# 13                          Chief, Fire Department   977915.05
# ...

# %%
avg = df.groupby('JobTitle')['TotalPayBenefits'].mean()
df9 = avg.sort_values(ascending=False).head(5)
df9
# Out:
# JobTitle
# Chief Investment Officer                          436224.360000
# Chief of Police                                   411732.266667
# Chief, Fire Department                            408865.326667
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    399211.275000
# Gen Mgr, Public Trnsp Dept                        380696.440000
# Name: TotalPayBenefits, dtype: float64

# %%
df['Benefits'] = df['Benefits'].fillna(0)
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %%
df11 = df.loc[df.groupby('Year')['TotalPay'].idxmax()][['Year', 'EmployeeName', 'TotalPay']]
df11
# Out:
#         Year    EmployeeName   TotalPay
# 0       2011  NATHANIEL FORD  567595.43
# 36159   2012  Gary Altenberg  362844.66
# 72927   2013     Samson  Lai  347102.32
# 110531  2014     David Shinn  471952.64

# %%
df12 = df.groupby('JobTitle').size()
df12
# Out:
# JobTitle
# ACCOUNT CLERK                                      83
# ACCOUNTANT                                          5
# ACCOUNTANT INTERN                                  48
# ACPO,JuvP, Juv Prob (SFERS)                         1
# ACUPUNCTURIST                                       1
#                                                  ...
# X-RAY LABORATORY AIDE                              26
# X-Ray Laboratory Aide                             100
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS      1
# Youth Comm Advisor                                  4
# ZOO CURATOR                                         1
# Length: 2159, dtype: int64
